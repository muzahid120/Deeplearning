# %%
import numpy as np 
import tensorflow
from tensorflow import keras
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import *
from keras.utils import pad_sequences

# %%
(x_train,y_train),(x_test,y_test)=imdb.load_data()

# %%
x_train=pad_sequences(x_train,padding='post',maxlen=100)
x_test=pad_sequences(x_test,padding='post',maxlen=100)

# %%
model=Sequential()
model.add(Embedding(input_dim=10000,output_dim=100,input_length=100))
model.add(SimpleRNN(32))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'],optimizer='adam')
history=model.fit(x_train,y_train ,epochs=10,validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[28], line 2
#       1 model.compile(loss='binary_crossentropy',metrics=['accuracy'],optimizer='adam')
# ----> 2 history=model.fit(x_train,y_train ,epochs=10,validation_data=(x_test,y_test))
#
# File c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\SDS\.conda\envs\test2\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential_7/embedding_7/embedding_lookup' defined at (most recent call last):
#     File "c:\Users\SDS\.conda\envs\test2\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\SDS\.conda\envs\test2\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\ipykernel\kernelapp.py", line 701, in start
#       self.io_loop.start()
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\SDS\.conda\envs\test2\lib\asyncio\windows_events.py", line 316, in run_forever
#       super().run_forever()
#     File "c:\Users\SDS\.conda\envs\test2\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "c:\Users\SDS\.conda\envs\test2\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "c:\Users\SDS\.conda\envs\test2\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#       await dispatch(*args)
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#       await result
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\SDS\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\SDS\AppData\Local\Temp\ipykernel_7916\2445814698.py", line 2, in <module>
#       history=model.fit(x_train,y_train ,epochs=10,validation_data=(x_test,y_test))
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\training.py", line 1742, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\training.py", line 1338, in train_function
#       return step_function(self, iterator)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\training.py", line 1322, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\training.py", line 1303, in run_step
#       outputs = model.train_step(data)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\training.py", line 1080, in train_step
#       y_pred = self(x, training=True)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\training.py", line 569, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\sequential.py", line 405, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\engine\base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\layers\core\embedding.py", line 272, in call
#       out = tf.nn.embedding_lookup(self.embeddings, inputs)
# Node: 'sequential_7/embedding_7/embedding_lookup'
# indices[25,9] = 10053 is not in [0, 10000)
# 	 [[{{node sequential_7/embedding_7/embedding_lookup}}]] [Op:__inference_train_function_76354]

# %%
import numpy as np 
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load IMDB dataset
vocab_size = 10000  # vocabulary size
max_len = 100  # maximum length of sequences
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

# Pad sequences
x_train = pad_sequences(x_train, maxlen=max_len, padding='post')
x_test = pad_sequences(x_test, maxlen=max_len, padding='post')

# Define the model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=100, input_length=max_len))
model.add(SimpleRNN(32))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 47s 57ms/step - loss: 0.5092 - accuracy: 0.7437 - val_loss: 0.4406 - val_accuracy: 0.8139
# Epoch 2/10
# 782/782 [==============================] - 44s 57ms/step - loss: 0.3362 - accuracy: 0.8603 - val_loss: 0.3951 - val_accuracy: 0.8222
# Epoch 3/10
# 782/782 [==============================] - 48s 61ms/step - loss: 0.2343 - accuracy: 0.9123 - val_loss: 0.4845 - val_accuracy: 0.7806
# Epoch 4/10
# 782/782 [==============================] - 44s 57ms/step - loss: 0.1635 - accuracy: 0.9418 - val_loss: 0.5678 - val_accuracy: 0.8040
# Epoch 5/10
# 782/782 [==============================] - 45s 57ms/step - loss: 0.1679 - accuracy: 0.9382 - val_loss: 0.6118 - val_accuracy: 0.7829
# Epoch 6/10
# 782/782 [==============================] - 45s 58ms/step - loss: 0.1089 - accuracy: 0.9662 - val_loss: 0.6717 - val_accuracy: 0.7799
# Epoch 7/10
# 782/782 [==============================] - 45s 57ms/step - loss: 0.0908 - accuracy: 0.9725 - val_loss: 0.7875 - val_accuracy: 0.7573
# Epoch 8/10
# 782/782 [==============================] - 44s 56ms/step - loss: 0.1947 - accuracy: 0.9215 - val_loss: 0.6591 - val_accuracy: 0.7127
# Epoch 9/10
# 782/782 [==============================] - 44s 56ms/step - loss: 0.0939 - accuracy: 0.9711 - val_loss: 0.8048 - val_accuracy: 0.7618
# Epoch 10/10
# 782/782 [==============================] - 44s 57ms/step - loss: 0.1150 - accuracy: 0.9590 - val_loss: 0.8473 - val_accuracy: 0.7085

# %%
import matplotlib.pyplot as plt 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],color='red')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'],color='red')
